# %%
from pytrends.request import TrendReq
import matplotlib as mpl
import pandas as pd

from bokeh.charts import TimeSeries, show, output_file
from bokeh.layouts import column

# %matplotlib inline
import datetime
from bokeh.plotting import figure, output_file, show, output_notebook
output_notebook()
import bokeh
# enter your own credentials
google_username = "data515gtrend@gmail.com"
google_password = "Data515gtrend123"
path = ""

# Login to Google. Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq(google_username, google_password, custom_useragent='My Pytrends Script')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e8242dea-0ca3-454a-9e50-6f64de331626">Loading BokehJS ...</span>
#     </div>

# %%
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=["Echo"], timeframe='2016-07-28 2016-10-27')#, "Kindle HD", "Fire", "Amazon Web Services," "AWS"])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()

# Interest by Region
interest_by_region_df = pytrend.interest_by_region()

# Related Queries, returns a dictionary of dataframes
related_queries_dict = pytrend.related_queries()

suggestions_dict = pytrend.suggestions(keyword='Amazon')

#print(suggestions_dict)

interest_over_time_df
# Out:
#             Echo
# date
# 2016-07-28    77
# 2016-07-29    75
# 2016-07-30    70
# 2016-07-31    69
# 2016-08-01    76
# 2016-08-02    75
# 2016-08-03    76
# 2016-08-04    76
# 2016-08-05    75
# 2016-08-06    68
# 2016-08-07    66
# 2016-08-08    76
# 2016-08-09    72
# 2016-08-10    74
# 2016-08-11    72
# 2016-08-12    71
# 2016-08-13    64
# 2016-08-14    61
# 2016-08-15    72
# 2016-08-16    75
# 2016-08-17    73
# 2016-08-18    74
# 2016-08-19    75
# 2016-08-20    68
# 2016-08-21    67
# 2016-08-22    74
# 2016-08-23    74
# 2016-08-24    74
# 2016-08-25    75
# 2016-08-26    73
# ...          ...
# 2016-09-28    76
# 2016-09-29    77
# 2016-09-30    76
# 2016-10-01    66
# 2016-10-02    65
# 2016-10-03    75
# 2016-10-04    79
# 2016-10-05    80
# 2016-10-06    77
# 2016-10-07    77
# 2016-10-08    69
# 2016-10-09    74
# 2016-10-10    81
# 2016-10-11    78
# 2016-10-12    82
# 2016-10-13    79
# 2016-10-14    76
# 2016-10-15    70
# 2016-10-16    70
# 2016-10-17    84
# 2016-10-18    80
# 2016-10-19    78
# 2016-10-20    85
# 2016-10-21    88
# 2016-10-22    79
# 2016-10-23    79
# 2016-10-24    85
# 2016-10-25    83
# 2016-10-26    86
# 2016-10-27    84
#
# [92 rows x 1 columns]

# %%
# %matplotlib inline
x = interest_over_time_df.index
y = interest_over_time_df['Echo']
date1 = x[0].date()

# %%
import numpy as np

# %%
plot = figure(plot_width=800, plot_height=400)
plot.circle(interest_over_time_df.index, interest_over_time_df['Echo'])
plot.line(interest_over_time_df.index, interest_over_time_df['Echo'])
plot.xaxis.axis_label = 'date'
plot.yaxis.axis_label = 'Alexa'
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9df0978b-4b47-4ecd-9de5-aacf4e50b57c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9df0978b-4b47-4ecd-9de5-aacf4e50b57c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9df0978b-4b47-4ecd-9de5-aacf4e50b57c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9df0978b-4b47-4ecd-9de5-aacf4e50b57c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c2682247-f52e-48d8-87a5-4dff68c3f0f0":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d529dc3-1667-440b-9efd-168a79f7d296","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e3a31ecc-8a38-4eda-9c7c-ccb276fb2470","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b33a4b6-4955-411a-9f8f-62ead064835e","type":"Line"},{"attributes":{"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"}},"id":"e6237d80-ade6-4c30-800c-b320d6c55ce2","type":"PanTool"},{"attributes":{"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"}},"id":"e6ee10fc-b809-4d7e-ba12-9e29edd1c8f4","type":"WheelZoomTool"},{"attributes":{},"id":"6e9d3b0a-cdd6-40e3-8100-1b496db7b2e7","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ab9da6c-768a-4588-a08b-e8971b32dbf4","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e6237d80-ade6-4c30-800c-b320d6c55ce2","type":"PanTool"},{"id":"e6ee10fc-b809-4d7e-ba12-9e29edd1c8f4","type":"WheelZoomTool"},{"id":"7ae77794-8ce6-4c68-9fe3-574d4aab8bea","type":"BoxZoomTool"},{"id":"6f117e4c-494d-4ddc-95ab-bae5199b697f","type":"SaveTool"},{"id":"633d1fbf-7e7e-4aa8-8c84-177a1b1ab91c","type":"ResetTool"},{"id":"5ac219c2-c074-4485-b9dd-b98120518562","type":"HelpTool"}]},"id":"9e540ef1-1da7-4c77-bb77-f50bd045f041","type":"Toolbar"},{"attributes":{"data_source":{"id":"2fc76c40-09df-439d-90da-0d9c895e52ad","type":"ColumnDataSource"},"glyph":{"id":"9b33a4b6-4955-411a-9f8f-62ead064835e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9ab9da6c-768a-4588-a08b-e8971b32dbf4","type":"Line"},"selection_glyph":null},"id":"9fe21183-d65d-465e-9e9b-bacdadd14a9a","type":"GlyphRenderer"},{"attributes":{"axis_label":"Alexa","formatter":{"id":"895a47a2-ef15-479e-832f-d6e900e54bec","type":"BasicTickFormatter"},"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"},"ticker":{"id":"16293adf-3171-4635-afd4-22a99e22a576","type":"BasicTicker"}},"id":"1512443b-dd00-4724-85d1-f0bac8c48ce4","type":"LinearAxis"},{"attributes":{"overlay":{"id":"e3a31ecc-8a38-4eda-9c7c-ccb276fb2470","type":"BoxAnnotation"},"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"}},"id":"7ae77794-8ce6-4c68-9fe3-574d4aab8bea","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"}},"id":"633d1fbf-7e7e-4aa8-8c84-177a1b1ab91c","type":"ResetTool"},{"attributes":{"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"},"ticker":{"id":"54ce303d-2e6d-4c3d-89e3-944fd8100a76","type":"BasicTicker"}},"id":"35935e38-0c37-4536-9939-c3214f611331","type":"Grid"},{"attributes":{},"id":"16293adf-3171-4635-afd4-22a99e22a576","type":"BasicTicker"},{"attributes":{"callback":null},"id":"d601c61a-82ac-4b3b-87eb-24635cca3c39","type":"DataRange1d"},{"attributes":{"plot":{"id":"b83078a3-8701-4c5c-827e-cab874196de0","subtype":"Figure","type":"Plot"}},"id":"6f117e4c-494d-4ddc-95ab-bae5199b697f","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[92]},"y":[77,75,70,69,76,75,76,76,75,68,66,76,72,74,72,71,64,61,72,75,73,74,75,68,67,74,74,74,75,73,64,65,69,74,76,73,71,65,64,73,72,71,72,69,62,64,71,73,100,93,86,72,67,78,77,75,72,73,68,66,75,72,76,77,76,66,65,75,79 ...

# %%
tsline = TimeSeries(interest_over_time_df,x =interest_over_time_df.index , y='Echo', title="Timeseries", ylabel='Amazon', xlabel='Date')

output_file("timeseries.html")

show(column(tsline, tspoint))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-25e4b7ceef4c> in <module>()
# ----> 1 tsline = TimeSeries(interest_over_time_df,x =interest_over_time_df.index , y='Echo', title="Timeseries", ylabel='Amazon', xlabel='Date')
#       2
#       3 output_file("timeseries.html")
#       4
#       5 show(column(tsline, tspoint))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/charts/builders/timeseries_builder.pyc in TimeSeries(data, x, y, builder_type, **kws)
#     102     kws['x'] = x
#     103     kws['y'] = y
# --> 104     return create_and_build(builder_type, data, **kws)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/charts/builder.pyc in create_and_build(builder_class, *data, **kws)
#      49     # create the new builder
#      50     builder_kws = {k: v for k, v in kws.items() if k in builder_props}
# ---> 51     builder = builder_class(*data, **builder_kws)
#      52
#      53     # create a chart to return, since there isn't one already
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/charts/builder.pyc in __init__(self, *args, **kws)
#     267             # make sure that the builder dimensions have access to the chart data source
#     268             for dim in self.dimensions:
# --> 269                 getattr(getattr(self, dim), 'set_data')(data)
#     270
#     271             # handle input attrs and ensure attrs have access to data
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/charts/properties.pyc in set_data(self, data)
#     170             data (`ChartDataSource`): the data source associated with the chart
#     171         """
# --> 172         self.selection = data[self.name]
#     173         self._chart_source = data
#     174         self._data = data.df
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/core/has_props.pyc in __setattr__(self, name, value)
#     267
#     268         if name in props or name in deprecated:
# --> 269             super(HasProps, self).__setattr__(name, value)
#     270         else:
#     271             matches, text = difflib.get_close_matches(name.lower(), props), "similar"
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/core/property/descriptors.pyc in __set__(self, obj, value, setter)
#     493             raise RuntimeError("%s.%s is a readonly property" % (obj.__class__.__name__, self.name))
#     494
# --> 495         self._internal_set(obj, value, setter)
#     496
#     497     def __delete__(self, obj):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/core/property/descriptors.pyc in _internal_set(self, obj, value, setter)
#     708
#     709         '''
# --> 710         value = self.property.prepare_value(obj, self.name, value)
#     711
#     712         old = self.__get__(obj, obj.__class__)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/bokeh/core/property/bases.pyc in prepare_value(self, obj_or_cls, name, value)
#     263                     break
#     264             else:
# --> 265                 raise e
#     266         else:
#     267             value = self.transform(value)
#
# ValueError: expected an element of either Column Name or Column String or List(Column Name or Column String), got DatetimeIndex(['2016-07-28', '2016-07-29', '2016-07-30', '2016-07-31',
#                '2016-08-01', '2016-08-02', '2016-08-03', '2016-08-04',
#                '2016-08-05', '2016-08-06', '2016-08-07', '2016-08-08',
#                '2016-08-09', '2016-08-10', '2016-08-11', '2016-08-12',
#                '2016-08-13', '2016-08-14', '2016-08-15', '2016-08-16',
#                '2016-08-17', '2016-08-18', '2016-08-19', '2016-08-20',
#                '2016-08-21', '2016-08-22', '2016-08-23', '2016-08-24',
#                '2016-08-25', '2016-08-26', '2016-08-27', '2016-08-28',
#                '2016-08-29', '2016-08-30', '2016-08-31', '2016-09-01',
#                '2016-09-02', '2016-09-03', '2016-09-04', '2016-09-05',
#                '2016-09-06', '2016-09-07', '2016-09-08', '2016-09-09',
#                '2016-09-10', '2016-09-11', '2016-09-12', '2016-09-13',
#                '2016-09-14', '2016-09-15', '2016-09-16', '2016-09-17',
#                '2016-09-18', '2016-09-19', '2016-09-20', '2016-09-21',
#                '2016-09-22', '2016-09-23', '2016-09-24', '2016-09-25',
#                '2016-09-26', '2016-09-27', '2016-09-28', '2016-09-29',
#                '2016-09-30', '2016-10-01', '2016-10-02', '2016-10-03',
#                '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07',
#                '2016-10-08', '2016-10-09', '2016-10-10', '2016-10-11',
#                '2016-10-12', '2016-10-13', '2016-10-14', '2016-10-15',
#                '2016-10-16', '2016-10-17', '2016-10-18', '2016-10-19',
#                '2016-10-20', '2016-10-21', '2016-10-22', '2016-10-23',
#                '2016-10-24', '2016-10-25', '2016-10-26', '2016-10-27'],
#               dtype='datetime64[ns]', name=u'date', freq=None)

# %%
y1
# Out:
# array([ 77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.])

# %%
related_queries_dict
# Out:
# {u'Alexa': {u'rising':                          query   value
#   0                   arri alexa  105200
#   1               alexa penavega   77750
#   2                  amazon echo   77600
#   3                  carlos pena   36200
#   4                     echo dot   27800
#   5              wwe alexa bliss   26500
#   6                  alexa feser   22050
#   7        alexa chung instagram   21750
#   8           alexa chung tumblr   20550
#   9           mulberry alexa bag   20450
#   10               alexa narvaez   18700
#   11            alexa amazon app   18450
#   12                 alexa losey   17450
#   13                    mulberry   17200
#   14              alexa commands   16750
#   15         alexa chung twitter   15700
#   16                alexa ilacad   15200
#   17            arri alexa price   14700
#   18         alexander skarsgard   13950
#   19              mulberry alexa   13850
#   20  carlos pena and alexa vega   13000
#   21        google home vs alexa   12600
#   22             carlos penavega   12300
#   23               machete kills   11200
#   24               big time rush   10850, u'top':               query  value
#   0       alexa chung    100
#   1        alexa vega     75
#   2   alexa and alexa     45
#   3      amazon alexa     25
#   4              alex     25
#   5        alex alexa     25
#   6        alexa rank     20
#   7      alexa berlin     15
#   8     alexa nikolas     15
#   9     alexa davalos     15
#   10      alexa bliss     15
#   11       echo alexa     15
#   12       alexa joel     10
#   13    alexa ranking     10
#   14       arri alexa     10
#   15         spy kids     10
#   16        alexa ray     10
#   17   mulberry alexa     10
#   18         mulberry     10
#   19   alexa penavega     10
#   20      amazon echo     10
#   21   alexa ray joel     10
#   22        alexa key      5
#   23    alexa website      5
#   24           alexis      5},
#  u'Echo': {u'rising':                            query  value
#   0                      echo 2014  46100
#   1                amazon echo dot  38950
#   2                      echo 2013  35650
#   3                      echo 2016  22500
#   4   linkin park lost in the echo  20000
#   5                          alexa  13600
#   6                   amazon alexa  12900
#   7                      echo 2015  12650
#   8                  earth to echo  10600
#   9                livescribe echo   9500
#   10                      echo dot   7850
#   11                     echo 2012   7500
#   12    google home vs amazon echo   6600
#   13         earth to echo trailer   6600
#   14                  echo newtech   5800
#   15                  echo of soul   5200
#   16       lost in the echo lyrics   5100
#   17              lost in the echo   4550
#   18            amazon echo review   4500
#   19                 echo new tech   4100
#   20          chicco echo stroller   3950
#   21                  kyocera echo   3450
#   22                  hecho o echo   2900
#   23         echo new tech network   2750
#   24                   amazon echo   2500, u'top':                query  value
#   0     echo liverpool    100
#   1          liverpool    100
#   2          echo dnia     90
#   3           the echo     80
#   4            de echo     55
#   5        amazon echo     45
#   6         daily echo     40
#   7          echo news     35
#   8   bournemouth echo     25
#   9        bournemouth     25
#   10         echo park     25
#   11          php echo     20
#   12        echo arena     20
#   13       echo online     15
#   14   sunderland echo     15
#   15     northern echo     15
#   16       echo kielce     15
#   17      evening echo     15
#   18       toyota echo     10
#   19             hecho     10
#   20          echo dot     10
#   21  echo dnia kielce     10
#   22     echo de menos     10
#   23       echo lyrics     10
#   24           echo tv     10},
#  u'Kindle': {u'rising':                        query   value
#   0             kindle fire hd  536850
#   1          kindle paperwhite  470400
#   2                       ipad  361350
#   3                kindle ipad  358750
#   4                 kindle app  340350
#   5         amazon kindle fire  257400
#   6                amazon fire  256800
#   7              kindle fire 7  132600
#   8                kindle apps  123200
#   9         kindle fire tablet  123000
#   10                kindle hdx  118850
#   11           kindle fire hdx  104900
#   12            nook vs kindle  101450
#   13          kindle unlimited   99500
#   14        kindle fire review   85000
#   15                      kobo   81500
#   16          kindle fire apps   79400
#   17             kindle update   75200
#   18            calibre kindle   71050
#   19                   calibre   69900
#   20           kindle for ipad   68250
#   21          kindle fire hd 7   66550
#   22             kindle fire 2   66500
#   23       kindle cloud reader   65650
#   24  amazon kindle paperwhite   62750, u'top':                   query  value
#   0           kindle fire    100
#   1         kindle amazon     80
#   2          kindle books     45
#   3             kindle hd     25
#   4        kindle fire hd     25
#   5     kindle paperwhite     20
#   6                  ipad     15
#   7           kindle ipad     15
#   8           kindle book     15
#   9            kindle app     15
#   10            my kindle     15
#   11      download kindle     15
#   12         kindle store     15
#   13        kindle reader     15
#   14          best kindle     10
#   15  amazon books kindle     10
#   16         amazon books     10
#   17                ebook     10
#   18   amazon kindle fire     10
#   19         kindle ebook     10
#   20          amazon fire     10
#   21           kindle pdf     10
#   22                 nook     10
#   23    kindle books free     10
#   24           free books     10}}
