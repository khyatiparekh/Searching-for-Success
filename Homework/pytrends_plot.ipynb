# %%
from pytrends.request import TrendReq
import matplotlib as mpl
import pandas as pd

from bokeh.charts import TimeSeries, show, output_file
from bokeh.layouts import column

# %matplotlib inline
import datetime
from bokeh.plotting import figure, output_file, show, output_notebook
output_notebook()
import bokeh
# enter your own credentials
google_username = "data515gtrend@gmail.com"
google_password = "Data515gtrend123"
path = ""

# Login to Google. Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq(google_username, google_password, custom_useragent='My Pytrends Script')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="637404f6-2945-491a-86c3-023f692c9d43">Loading BokehJS ...</span>
#     </div>

# %%
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=["Echo"], timeframe='2016-07-28 2016-10-27')#, "Kindle HD", "Fire", "Amazon Web Services," "AWS"])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()

# Interest by Region
interest_by_region_df = pytrend.interest_by_region()

# Related Queries, returns a dictionary of dataframes
related_queries_dict = pytrend.related_queries()

suggestions_dict = pytrend.suggestions(keyword='Amazon')

#print(suggestions_dict)

interest_over_time_df
# Out:
#             Echo
# date
# 2016-07-28    78
# 2016-07-29    75
# 2016-07-30    70
# 2016-07-31    69
# 2016-08-01    75
# 2016-08-02    75
# 2016-08-03    76
# 2016-08-04    75
# 2016-08-05    74
# 2016-08-06    69
# 2016-08-07    68
# 2016-08-08    76
# 2016-08-09    72
# 2016-08-10    75
# 2016-08-11    73
# 2016-08-12    71
# 2016-08-13    64
# 2016-08-14    62
# 2016-08-15    70
# 2016-08-16    75
# 2016-08-17    72
# 2016-08-18    73
# 2016-08-19    73
# 2016-08-20    66
# 2016-08-21    65
# 2016-08-22    74
# 2016-08-23    75
# 2016-08-24    75
# 2016-08-25    76
# 2016-08-26    72
# ...          ...
# 2016-09-28    77
# 2016-09-29    75
# 2016-09-30    73
# 2016-10-01    67
# 2016-10-02    65
# 2016-10-03    75
# 2016-10-04    79
# 2016-10-05    81
# 2016-10-06    76
# 2016-10-07    76
# 2016-10-08    69
# 2016-10-09    73
# 2016-10-10    81
# 2016-10-11    80
# 2016-10-12    82
# 2016-10-13    81
# 2016-10-14    77
# 2016-10-15    71
# 2016-10-16    71
# 2016-10-17    84
# ...

# %%
# %matplotlib inline
x = interest_over_time_df.index
y = interest_over_time_df['Echo']

# %%
import numpy as np

# %%
#plot = figure(plot_width=800, plot_height=400)
#plot.circle(ts, interest_over_time_df['Echo'])
#plot.line(ts, interest_over_time_df['Echo'])
#plot.xaxis.axis_label = 'date'
#plot.yaxis.axis_label = 'Alexa'
#show(plot)
output_file("timeseries.html")
p = TimeSeries(interest_over_time_df)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8646e1ef-9b3e-42b5-975c-40965ca7eb8c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.plotting import figure

p1 = figure(plot_width=300, plot_height=300, ylabel='Interest in Amazon', xlabel='Date')
p1.line(interest_over_time_df, y='Echo', line_width=2, color="#1f77b4", alpha=0.5, legend=True)
tab1 = Panel(child=p1, title="Line Timeseries")

p2 = figure(plot_width=300, plot_height=300, ylabel='Interest in Amazon', xlabel='Date')
p2.circle(interest_over_time_df, y = 'Echo', color = "firebrick", legend=True)
tab2 = Panel(child=p2, title="Scatterplot Timeseries")

tabs = Tabs(tabs=[ tab1, tab2 ])

output_file("timeseries.html")
show(tabs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-39fd5069a344> in <module>()
#       1 from bokeh.models.widgets import Button, RadioButtonGroup, Select, Slider, Panel, Tabs
#       2
# ----> 3 p1 = figure(plot_width=300, plot_height=300, ylabel='Interest in Amazon', xlabel='Date')
#       4 p1.line(interest_over_time_df, y='Echo', line_width=2, color="#1f77b4", alpha=0.5, legend=True)
#       5 tab1 = Panel(child=p1, title="Line Timeseries")
#
# C:\Users\aerin\Anaconda3\envs\Pandas\lib\site-packages\bokeh\plotting\figure.py in figure(**kwargs)
#     650     '''
#     651
# --> 652     return Figure(**kwargs)
#     653
#     654
#
# C:\Users\aerin\Anaconda3\envs\Pandas\lib\site-packages\bokeh\plotting\figure.py in __init__(self, *arg, **kw)
#     114             kw['title'] = Title(text=title)
#     115
# ...

# %%
# timeseries plot with all keywords & stock price plotted
TOOLS = "crosshair, pan, wheel_zoom, box_zoom, reset, tap, box_select, lasso_select"
p = figure(tools=TOOLS)
p.axis.major_label_text_font_size = "16pt"
hover = HoverTool(tooltips='<font face="Arial" size="3">@y_text @desc in @x</font>', mode="vline")
p.add_tools(hover)

tsline = TimeSeries(data,
    x='Date', 
    y=['AMZN Stock Price','AMZN Interest: Echo', 'AMZN Negative: Amazon Sucks',
       'AMZN Positive: search term'],
    color=['AMZN Stock Price','AMZN Interest: Echo', 'AMZN Negative: Amazon Sucks',
           'AMZN Positive: search term'],
    dash=['AMZN Interest: Echo', 'AMZN Negative: Amazon Sucks',
          'AMZN Positive: search term'],
    title="Amazon Timeseries", ylabel='Amazon Stock Prices and Popular Sentiment', legend=True)

tspoint = TimeSeries(data,
    x='Date', y=['IBM', 'MSFT', 'AAPL'],
    color=['IBM', 'MSFT', 'AAPL'], dash=['IBM', 'MSFT', 'AAPL'],
    builder_type='point', title="Timeseries Points",
    ylabel='Stock Prices', legend=True)

    # push updates to the plot continuously using the handle (intererrupt the notebook kernel to stop)
    push_notebook(handle=target)
    time.sleep(0.1)

# Update the hover glyph propertes using the explicit handle (go hover over the plot)
r.hover_glyph.fill_color = "white"
r.hover_glyph.fill_alpha = 0.5
hover.mode = "vline"
interact_plot = push_notebook()

# %%
from bokeh.charts import Bar, output_file, show
from bokeh.sampledata.autompg import autompg as df

p = Bar(df, label='yr', values='mpg', agg='median', group='origin',
        title="Median MPG by YR, grouped by ORIGIN", legend='top_right')

output_file("bar.html")

show(p)

# %%
y1
# Out:
# array([ 77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,  77.,
#         77.,  77.,  77.,  77.])

# %%
related_queries_dict
# Out:
# {u'Alexa': {u'rising':                          query   value
#   0                   arri alexa  105200
#   1               alexa penavega   77750
#   2                  amazon echo   77600
#   3                  carlos pena   36200
#   4                     echo dot   27800
#   5              wwe alexa bliss   26500
#   6                  alexa feser   22050
#   7        alexa chung instagram   21750
#   8           alexa chung tumblr   20550
#   9           mulberry alexa bag   20450
#   10               alexa narvaez   18700
#   11            alexa amazon app   18450
#   12                 alexa losey   17450
#   13                    mulberry   17200
#   14              alexa commands   16750
#   15         alexa chung twitter   15700
#   16                alexa ilacad   15200
#   17            arri alexa price   14700
#   18         alexander skarsgard   13950
#   19              mulberry alexa   13850
#   20  carlos pena and alexa vega   13000
# ...
