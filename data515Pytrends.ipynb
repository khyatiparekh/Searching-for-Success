# %%
from bokeh.plotting import figure, output_file, show, output_notebook, vplot
output_notebook()
import bokeh

from pytrends.request import TrendReq
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="65643aa0-94bc-4787-83f5-994cf60090cb">Loading BokehJS ...</span>
#     </div>

# %%
# enter your own credentials
google_username = "data515gtrend@gmail.com"
google_password = "Data515gtrend123"
path = ""

# Login to Google. Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq(google_username, google_password, custom_useragent='My Pytrends Script')

# %%
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Echo'], timeframe='2016-07-28 2016-10-27')#, "Kindle HD", "Fire", "Amazon Web Services," "AWS"])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()

# Interest by Region
interest_by_region_df = pytrend.interest_by_region()

# Related Queries, returns a dictionary of dataframes
related_queries_dict = pytrend.related_queries()

# Get Google Hot Trends data
#trending_searches_df = pytrend.trending_searches()

# Get Google Top Charts
#top_charts_df = pytrend.top_charts(cid='actors', date=201611)

# Get Google Keyword Suggestions
#suggestions_dict = pytrend.suggestions(keyword='pizza')

# %%
df = interest_over_time_df
df
# Out:
#             Echo
# date
# 2016-07-28    77
# 2016-07-29    75
# 2016-07-30    70
# 2016-07-31    69
# 2016-08-01    76
# 2016-08-02    75
# 2016-08-03    76
# 2016-08-04    76
# 2016-08-05    75
# 2016-08-06    68
# 2016-08-07    66
# 2016-08-08    76
# 2016-08-09    72
# 2016-08-10    74
# 2016-08-11    72
# 2016-08-12    71
# 2016-08-13    64
# 2016-08-14    61
# 2016-08-15    72
# 2016-08-16    75
# 2016-08-17    73
# 2016-08-18    74
# 2016-08-19    75
# 2016-08-20    68
# 2016-08-21    67
# 2016-08-22    74
# 2016-08-23    74
# 2016-08-24    74
# 2016-08-25    75
# 2016-08-26    73
# ...          ...
# 2016-09-28    76
# 2016-09-29    77
# 2016-09-30    76
# 2016-10-01    66
# 2016-10-02    65
# 2016-10-03    75
# 2016-10-04    79
# 2016-10-05    80
# 2016-10-06    77
# 2016-10-07    77
# 2016-10-08    69
# 2016-10-09    74
# 2016-10-10    81
# 2016-10-11    78
# 2016-10-12    82
# 2016-10-13    79
# 2016-10-14    76
# 2016-10-15    70
# 2016-10-16    70
# 2016-10-17    84
# 2016-10-18    80
# 2016-10-19    78
# 2016-10-20    85
# 2016-10-21    88
# 2016-10-22    79
# 2016-10-23    79
# 2016-10-24    85
# 2016-10-25    83
# 2016-10-26    86
# 2016-10-27    84
#
# [92 rows x 1 columns]

# %%
import csv

with open('interest_over_time.csv', 'ab') as f:
    writer = csv.DictWriter(f, ( 'Echo'))
    writer.writerow(df)

# %%
plot = figure(plot_width=400, plot_height=400)
plot.circle(df.index, df['Echo'])
plot.xaxis.axis_label = 'rate'
plot.yaxis.axis_label = 'yield'
show(plot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-aa3e77ab9e6a> in <module>()
#       3 plot.xaxis.axis_label = 'rate'
#       4 plot.yaxis.axis_label = 'yield'
# ----> 5 show(plot)
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/io.pyc in show(obj, browser, new, notebook_handle)
#     297     '''
#     298     if obj not in _state.document.roots:
# --> 299         _state.document.add_root(obj)
#     300     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     301
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/document.pyc in add_root(self, model, setter)
#     526             self._roots.append(model)
#     527         finally:
# --> 528             self._pop_all_models_freeze()
#     529         self._trigger_on_change(RootAddedEvent(self, model, setter))
#     530
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/document.pyc in _pop_all_models_freeze(self)
#     383         self._all_models_freeze_count -= 1
#     384         if self._all_models_freeze_count == 0:
# --> 385             self._recompute_all_models()
#     386
#     387     def _invalidate_all_models(self):
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/document.pyc in _recompute_all_models(self)
#     393         new_all_models_set = set()
#     394         for r in self.roots:
# --> 395             new_all_models_set = new_all_models_set.union(r.references())
#     396         old_all_models_set = set(self._all_models.values())
#     397         to_detach = old_all_models_set - new_all_models_set
#
# AttributeError: 'function' object has no attribute 'references'

# %%
import pandas as pd
from bokeh.charts import Bar, output_file, show
from bokeh.models import FuncTickFormatter

dates = df.index
p = Bar(df, 'index', values='pct jobs with skill', title="Top skills for ___ jobs", legend=False)
label_dict = {}
for i, s in enumerate(skills_list):
    label_dict[i] = s

p.xaxis.formatter = FuncTickFormatter(code="""
    var labels = %s;
    return labels[tick];
""" % label_dict)

output_file("bar.html")
show(p)

# %%
import pandas as pd
from bokeh.charts import Bar, output_file, show
from bokeh.models import FuncTickFormatter

skills_list = ['cheese making', 'squanching', 'leaving harsh criticisms']
pct_counts = [25, 40, 1]
df = pd.DataFrame({'skill':skills_list, 'pct jobs with skill':pct_counts})
p = Bar(df, 'index', values='pct jobs with skill', title="Top skills for ___ jobs", legend=False)
label_dict = {}
for i, s in enumerate(skills_list):
    label_dict[i] = s

p.xaxis.formatter = FuncTickFormatter(code="""
    var labels = %s;
    return labels[tick];
""" % label_dict)

output_file("bar.html")
show(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-c332aed3c43d> in <module>()
#      17
#      18 output_file("bar.html")
# ---> 19 show(p)
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/io.pyc in show(obj, browser, new, notebook_handle)
#     297     '''
#     298     if obj not in _state.document.roots:
# --> 299         _state.document.add_root(obj)
#     300     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     301
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/document.pyc in add_root(self, model, setter)
#     526             self._roots.append(model)
#     527         finally:
# --> 528             self._pop_all_models_freeze()
#     529         self._trigger_on_change(RootAddedEvent(self, model, setter))
#     530
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/document.pyc in _pop_all_models_freeze(self)
#     383         self._all_models_freeze_count -= 1
#     384         if self._all_models_freeze_count == 0:
# --> 385             self._recompute_all_models()
#     386
#     387     def _invalidate_all_models(self):
#
# /Users/tondapu/anaconda/lib/python2.7/site-packages/bokeh/document.pyc in _recompute_all_models(self)
#     393         new_all_models_set = set()
#     394         for r in self.roots:
# --> 395             new_all_models_set = new_all_models_set.union(r.references())
#     396         old_all_models_set = set(self._all_models.values())
#     397         to_detach = old_all_models_set - new_all_models_set
#
# AttributeError: 'function' object has no attribute 'references'
