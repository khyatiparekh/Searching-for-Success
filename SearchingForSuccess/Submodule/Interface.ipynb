# %%
# Import Libraries
import EarningReport
import PredictionStockPrice
import HistoricalDataPlot
# %matplotlib inline

# %%
def show_menu():       
    print (12 * "-" , " Select Company:" , 12 * "-")
    print ("1. Amazon")
    print ("2. Google")
    print ("3. Microsoft")
    print (46 * "-")

# %%
 if __name__ == "__main__":
    show_menu()
    option = int(input("Enter the number of your choice: "))
    if option == 1:
        company = "Amazon"
    elif option == 2:
        company = "Google"
    elif option == 3:
        company = "Microsoft"
    else:
        print("Invalid option.")
    EarningReport.get_current_quarter_dates()
    EarningReport.show_last_day_quarter()
    EarningReport.get_earnings_data(company)
    print("Predicted probability the stock price will increase after the earning report is released:",
          PredictionStockPrice.prediction_stock_price(company))
    HistoricalDataPlot.historical_data_plot(company)
# Out:
# ------------  Select Company: ------------
# 1. Amazon
# 2. Google
# 3. Microsoft
# ----------------------------------------------
# Enter the number of your choice: 1
# Current Quarter: 04-01-2017 to 06-30-2017
# The current fiscal quarter ends on June 30, 2017.
#
# The next earnings report from Amazon is expected: July 25, 2017 - July 30, 2017.
#
# Predicted probability the stock price will increase after the earning report is released: 0.589
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5e3072f5-8414-4a29-9985-8bbe4daad3c0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1a3199b7-9811-4c68-a1c4-30be9c9a2280"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
# ...
